# %%
#Load dependencies
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Data

# %%
#Add local folder path
folder_path_5y = 'data/5Y'

#Add local filepaths
csv_files = [f for f in os.listdir(folder_path_5y) 
            if f.endswith('Data.csv')]

#Create and combine all individual dataframes
dfs = []

for file in csv_files:
    file_path = os.path.join(folder_path_5y, file)
    
    df = pd.read_csv(file_path, header=0)
    
    df['source_file'] = file
    
    dfs.append(df)

combined_df = pd.concat(dfs, axis=0, ignore_index=True)

# %%
print(f"Combined DataFrame shape: {combined_df.shape}")
combined_df.head(300)
# Out:
# Combined DataFrame shape: (3875, 132)
#              GEO_ID                  NAME               S1901_C01_001E  \
# 0         Geography  Geographic Area Name  Households!!Estimate!!Total
# 1       0400000US49                  Utah                       871358
# 2    8600000US81324           ZCTA5 81324                          572
# 3    8600000US82930           ZCTA5 82930                         5144
# 4    8600000US83312           ZCTA5 83312                           45
# ..              ...                   ...                          ...
# 295  8600000US86514           ZCTA5 86514                          770
# 296       Geography  Geographic Area Name  Households!!Estimate!!Total
# 297     0400000US49                  Utah                       880873
# 298  8600000US81324           ZCTA5 81324                          518
# 299  8600000US82930           ZCTA5 82930                         4957
#
#                          S1901_C01_001M             S1901_C02_001E  \
# 0    Households!!Margin of Error!!Total  Families!!Estimate!!Total
# 1                                  2763                     654354
# 2                                    84                        415
# 3                                   296                       3706
# 4                                    39                         45
# ..                                  ...                        ...
# 295                                  85                        542
# 296  Households!!Margin of Error!!Total  Families!!Estimate!!Total
# 297                                2335                     659829
# 298                                  81                        360
# 299                                 291                       3677
#
#                        S1901_C02_001M  \
# 0    Families!!Margin of Error!!Total
# 1                                3519
# 2                                  57
# 3                                 303
# 4                                  39
# ..                                ...
# 295                                72
# 296  Families!!Margin of Error!!Total
# 297                              3220
# 298                                59
# 299                               299
#
#                                S1901_C03_001E  \
# 0    Married-couple families!!Estimate!!Total
# 1                                      536979
# 2                                         359
# 3                                        2967
# 4                                          45
# ..                                        ...
# 295                                       268
# 296  Married-couple families!!Estimate!!Total
# 297                                    538595
# 298                                       315
# 299                                      2910
#
#                                       S1901_C03_001M  \
# 0    Married-couple families!!Margin of Error!!Total
# 1                                               3904
# 2                                                 60
# 3                                                305
# 4                                                 39
# ..                                               ...
# 295                                               50
# 296  Married-couple families!!Margin of Error!!Total
# 297                                             3885
# 298                                               59
# 299                                              298
#
#                             S1901_C04_001E  \
# 0    Nonfamily households!!Estimate!!Total
# 1                                   217004
# 2                                      157
# 3                                     1438
# 4                                        0
# ..                                     ...
# 295                                    228
# 296  Nonfamily households!!Estimate!!Total
# 297                                 221044
# 298                                    158
# 299                                   1280
#
#                                    S1901_C04_001M  ...  \
# 0    Nonfamily households!!Margin of Error!!Total  ...
# 1                                            2609  ...
# 2                                              58  ...
# 3                                             240  ...
# 4                                              89  ...
# ..                                            ...  ...
# 295                                            62  ...
# 296  Nonfamily households!!Margin of Error!!Total  ...
# 297                                          2613  ...
# 298                                            54  ...
# 299                                           227  ...
#
#                                         S1901_C01_016E  \
# 0    Households!!Estimate!!PERCENT IMPUTED!!Nonfami...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 295                                                (X)
# 296  Households!!Estimate!!PERCENT IMPUTED!!Nonfami...
# 297                                                (X)
# 298                                                (X)
# 299                                                (X)
#
#                                         S1901_C01_016M  \
# 0    Households!!Margin of Error!!PERCENT IMPUTED!!...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 295                                                (X)
# 296  Households!!Margin of Error!!PERCENT IMPUTED!!...
# 297                                                (X)
# 298                                                (X)
# 299                                                (X)
#
#                                         S1901_C02_016E  \
# 0    Families!!Estimate!!PERCENT IMPUTED!!Nonfamily...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 295                                                (X)
# 296  Families!!Estimate!!PERCENT IMPUTED!!Nonfamily...
# 297                                                (X)
# 298                                                (X)
# 299                                                (X)
#
#                                         S1901_C02_016M  \
# 0    Families!!Margin of Error!!PERCENT IMPUTED!!No...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 295                                                (X)
# 296  Families!!Margin of Error!!PERCENT IMPUTED!!No...
# 297                                                (X)
# 298                                                (X)
# 299                                                (X)
#
#                                         S1901_C03_016E  \
# 0    Married-couple families!!Estimate!!PERCENT IMP...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 295                                                (X)
# 296  Married-couple families!!Estimate!!PERCENT IMP...
# 297                                                (X)
# 298                                                (X)
# 299                                                (X)
#
#                                         S1901_C03_016M  \
# 0    Married-couple families!!Margin of Error!!PERC...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 295                                                (X)
# 296  Married-couple families!!Margin of Error!!PERC...
# 297                                                (X)
# 298                                                (X)
# 299                                                (X)
#
#                                         S1901_C04_016E  \
# 0    Nonfamily households!!Estimate!!PERCENT IMPUTE...
# 1                                                 23.5
# 2                                                 24.8
# 3                                                 16.4
# 4                                                    -
# ..                                                 ...
# 295                                               17.1
# 296  Nonfamily households!!Estimate!!PERCENT IMPUTE...
# 297                                               24.3
# 298                                               33.5
# 299                                               18.2
#
#                                         S1901_C04_016M Unnamed: 130  \
# 0    Nonfamily households!!Margin of Error!!PERCENT...          NaN
# 1                                                  (X)          NaN
# 2                                                  (X)          NaN
# 3                                                  (X)          NaN
# 4                                                  (X)          NaN
# ..                                                 ...          ...
# 295                                                (X)          NaN
# 296  Nonfamily households!!Margin of Error!!PERCENT...          NaN
# 297                                                (X)          NaN
# 298                                                (X)          NaN
# 299                                                (X)          NaN
#
#                     source_file
# 0    ACSST5Y2011.S1901-Data.csv
# 1    ACSST5Y2011.S1901-Data.csv
# 2    ACSST5Y2011.S1901-Data.csv
# 3    ACSST5Y2011.S1901-Data.csv
# 4    ACSST5Y2011.S1901-Data.csv
# ..                          ...
# 295  ACSST5Y2011.S1901-Data.csv
# 296  ACSST5Y2012.S1901-Data.csv
# 297  ACSST5Y2012.S1901-Data.csv
# 298  ACSST5Y2012.S1901-Data.csv
# 299  ACSST5Y2012.S1901-Data.csv
#
# [300 rows x 132 columns]

# %% [markdown]
# ## Clean Data

# %% [markdown]
# #### Handle Missing Data

# %%
#Different values to set as NA for filtering of columns and imputation later
na_strings_list = [
    "**",  #Margin of error column - no sample or too few samples for standard error
    "-",   #Estimate column - no sample or too few samples for estimate or ratio of medians issue
    "-",   #Following median estimate - median falls in lowest interval of open-ended distribution
    "+",   #Following median estimate - median falls in upper interval of open-ended distribution
    "***", #Margin of error column - median in lowest/upper interval of open-ended distribution
    "*****", #Margin of error column - estimate is controlled
    "N",   #Estimate and margin of error columns - data cannot be displayed (sample too small)
    "(X)"  #Estimate not applicable or not available
]

# %%
#Replace special character values with np.nan values
cleaned_df = combined_df.replace(na_strings_list, np.nan)

#Check nan value counts
missing_counts = cleaned_df.isna().sum().sort_values(ascending=False)
print(missing_counts)

#Filter out columns with >200 missing values (arbitrary decision, would consider more if there was a specific use case for this project)
na_columns = missing_counts[missing_counts > 200].index.tolist()

cleaned_df = cleaned_df.drop(columns=na_columns)
cleaned_df.head(5)
# Out:
# Unnamed: 130      3875
# S1901_C02_016E    3862
# S1901_C01_015M    3862
# S1901_C03_016E    3862
# S1901_C02_015M    3862
#                   ...
# S1901_C03_001E       0
# S1901_C02_001E       0
# S1901_C02_001M       0
# S1901_C03_001M       0
# source_file          0
# Length: 132, dtype: int64
#            GEO_ID                  NAME               S1901_C01_001E  \
# 0       Geography  Geographic Area Name  Households!!Estimate!!Total
# 1     0400000US49                  Utah                       871358
# 2  8600000US81324           ZCTA5 81324                          572
# 3  8600000US82930           ZCTA5 82930                         5144
# 4  8600000US83312           ZCTA5 83312                           45
#
#                        S1901_C01_001M             S1901_C02_001E  \
# 0  Households!!Margin of Error!!Total  Families!!Estimate!!Total
# 1                                2763                     654354
# 2                                  84                        415
# 3                                 296                       3706
# 4                                  39                         45
#
#                      S1901_C02_001M                            S1901_C03_001E  \
# 0  Families!!Margin of Error!!Total  Married-couple families!!Estimate!!Total
# 1                              3519                                    536979
# 2                                57                                       359
# 3                               303                                      2967
# 4                                39                                        45
#
#                                     S1901_C03_001M  \
# 0  Married-couple families!!Margin of Error!!Total
# 1                                             3904
# 2                                               60
# 3                                              305
# 4                                               39
#
#                           S1901_C04_001E  \
# 0  Nonfamily households!!Estimate!!Total
# 1                                 217004
# 2                                    157
# 3                                   1438
# 4                                      0
#
#                                  S1901_C04_001M  ...  \
# 0  Nonfamily households!!Margin of Error!!Total  ...
# 1                                          2609  ...
# 2                                            58  ...
# 3                                           240  ...
# 4                                            89  ...
#
#                                   S1901_C01_011M  \
# 0  Households!!Margin of Error!!$200,000 or more
# 1                                            0.1
# 2                                            5.5
# 3                                            1.2
# 4                                           44.2
#
#                          S1901_C02_011E  \
# 0  Families!!Estimate!!$200,000 or more
# 1                                   4.1
# 2                                   0.0
# 3                                   2.4
# 4                                   0.0
#
#                                 S1901_C02_011M  \
# 0  Families!!Margin of Error!!$200,000 or more
# 1                                          0.1
# 2                                          7.5
# 3                                          1.7
# 4                                         44.2
#
#                                       S1901_C03_011E  \
# 0  Married-couple families!!Estimate!!$200,000 or...
# 1                                                4.7
# 2                                                0.0
# 3                                                3.0
# 4                                                0.0
#
#                                       S1901_C03_011M  \
# 0  Married-couple families!!Margin of Error!!$200...
# 1                                                0.2
# 2                                                8.6
# 3                                                2.1
# 4                                               44.2
#
#                                 S1901_C01_013E  \
# 0  Households!!Estimate!!Mean income (dollars)
# 1                                        72305
# 2                                        50057
# 3                                        69452
# 4                                        65527
#
#                                       S1901_C01_013M  \
# 0  Households!!Margin of Error!!Mean income (doll...
# 1                                                436
# 2                                               7443
# 3                                               6380
# 4                                              28396
#
#                                       S1901_C01_014E  \
# 0  Households!!Estimate!!PERCENT IMPUTED!!Househo...
# 1                                               23.6
# 2                                               29.9
# 3                                               18.7
# 4                                               35.6
#
#                                       S1901_C02_015E  \
# 0  Families!!Estimate!!PERCENT IMPUTED!!Family in...
# 1                                               22.9
# 2                                               31.8
# 3                                               19.1
# 4                                               35.6
#
#                   source_file
# 0  ACSST5Y2011.S1901-Data.csv
# 1  ACSST5Y2011.S1901-Data.csv
# 2  ACSST5Y2011.S1901-Data.csv
# 3  ACSST5Y2011.S1901-Data.csv
# 4  ACSST5Y2011.S1901-Data.csv
#
# [5 rows x 75 columns]

# %%
#Check nan value counts again
missing_counts = cleaned_df.isna().sum().sort_values(ascending=False)
print(missing_counts)
# Out:
# S1901_C01_013M    142
# S1901_C01_013E    142
# S1901_C03_009M     85
# S1901_C03_003E     85
# S1901_C03_003M     85
#                  ...
# S1901_C03_001E      0
# S1901_C02_001E      0
# S1901_C02_001M      0
# S1901_C01_001M      0
# source_file         0
# Length: 75, dtype: int64

# %% [markdown]
# #### Remove Duplicate Rows

# %%
#Remove duplicate rows (while accounting for minor difference due to source_file column)
non_id_list = list(cleaned_df.columns)
non_id_list.remove('source_file')

print(cleaned_df.duplicated(subset=non_id_list).sum())
cleaned_df.drop_duplicates(keep='first', inplace=True)
# Out:
# 52

# %% [markdown]
# #### Replace Column Header

# %%
#Set column headers to more detailed description
cleaned_df.columns = cleaned_df.iloc[0]
cleaned_df = cleaned_df.iloc[1:].reset_index(drop=True)

# %% [markdown]
# #### Remove Aggregated Utah Statistics

# %%
#Get rid of aggregated Utah rows (we only want zip code level data)
cleaned_df = cleaned_df[cleaned_df['Geographic Area Name'] != 'Utah']

# %% [markdown]
# #### Create Zip Code and Year Variables

# %%
#Create zip_code column
cleaned_df['zip_code'] = cleaned_df['Geographic Area Name'].str[-5:]

#Create year column
cleaned_df['year'] = cleaned_df['ACSST5Y2011.S1901-Data.csv'].str.extract(r'Y(\d{4})\.', expand=False).astype(int)

# %% [markdown]
# #### Cast Dataframe Numeric Variables

# %%
#Convert dataframe numeric variables to numeric datatypes
numeric_columns = list(cleaned_df.columns)
string_columns = ['Geography', 'Geographic Area Name', 'ACSST5Y2011.S1901-Data.csv']
numeric_columns = [x for x in numeric_columns if x not in string_columns]

cleaned_df[numeric_columns] = cleaned_df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# #### Impute Remaining Missing Values Based on Column Median

# %%
def impute_missing_values(df):
    #Separate numeric and non-numeric columns
    numeric_cols = df.select_dtypes(include=['number']).columns

    fill_values = {}

    #Impute numeric columns with median (robust to outliers)
    for col in numeric_cols:
        fill_values[col] = df[col].median()

    #Fill missing values
    return df.fillna(fill_values)

# %%
imputed_df = impute_missing_values(cleaned_df)

imputed_df.head(imputed_df.shape[0])
# Out:
# 0          Geography Geographic Area Name  Households!!Estimate!!Total  \
# 1     8600000US81324          ZCTA5 81324                        572.0
# 2     8600000US82930          ZCTA5 82930                       5144.0
# 3     8600000US83312          ZCTA5 83312                         45.0
# 4     8600000US83342          ZCTA5 83342                        456.0
# 5     8600000US84001          ZCTA5 84001                        271.0
# ...              ...                  ...                          ...
# 3869  860Z200US84783          ZCTA5 84783                        478.0
# 3870  860Z200US84784          ZCTA5 84784                        220.0
# 3871  860Z200US84790          ZCTA5 84790                      18477.0
# 3872  860Z200US86044          ZCTA5 86044                       1134.0
# 3873  860Z200US86514          ZCTA5 86514                        792.0
#
# 0     Households!!Margin of Error!!Total  Families!!Estimate!!Total  \
# 1                                   84.0                      415.0
# 2                                  296.0                     3706.0
# 3                                   39.0                       45.0
# 4                                   83.0                      367.0
# 5                                   96.0                      233.0
# ...                                  ...                        ...
# 3869                               137.0                      334.0
# 3870                                60.0                      220.0
# 3871                               913.0                    13910.0
# 3872                               126.0                      711.0
# 3873                                89.0                      561.0
#
# 0     Families!!Margin of Error!!Total  \
# 1                                 57.0
# 2                                303.0
# 3                                 39.0
# 4                                 89.0
# 5                                 97.0
# ...                                ...
# 3869                             111.0
# 3870                              60.0
# 3871                             784.0
# 3872                             109.0
# 3873                              88.0
#
# 0     Married-couple families!!Estimate!!Total  \
# 1                                        359.0
# 2                                       2967.0
# 3                                         45.0
# 4                                        358.0
# 5                                        200.0
# ...                                        ...
# 3869                                     334.0
# 3870                                     119.0
# 3871                                   11586.0
# 3872                                     342.0
# 3873                                     266.0
#
# 0     Married-couple families!!Margin of Error!!Total  \
# 1                                                60.0
# 2                                               305.0
# 3                                                39.0
# 4                                                90.0
# 5                                                87.0
# ...                                               ...
# 3869                                            111.0
# 3870                                             53.0
# 3871                                            686.0
# 3872                                             77.0
# 3873                                             68.0
#
# 0     Nonfamily households!!Estimate!!Total  \
# 1                                     157.0
# 2                                    1438.0
# 3                                       0.0
# 4                                      89.0
# 5                                      38.0
# ...                                     ...
# 3869                                  144.0
# 3870                                    0.0
# 3871                                 4567.0
# 3872                                  423.0
# 3873                                  231.0
#
# 0     Nonfamily households!!Margin of Error!!Total  ...  \
# 1                                             58.0  ...
# 2                                            240.0  ...
# 3                                             89.0  ...
# 4                                             43.0  ...
# 5                                             24.0  ...
# ...                                            ...  ...
# 3869                                         101.0  ...
# 3870                                          12.0  ...
# 3871                                         629.0  ...
# 3872                                          99.0  ...
# 3873                                          47.0  ...
#
# 0     Families!!Margin of Error!!$200,000 or more  \
# 1                                             7.5
# 2                                             1.7
# 3                                            44.2
# 4                                             8.5
# 5                                            13.0
# ...                                           ...
# 3869                                         15.9
# 3870                                         12.2
# 3871                                          2.9
# 3872                                          4.5
# 3873                                          4.5
#
# 0     Married-couple families!!Estimate!!$200,000 or more  \
# 1                                                   0.0
# 2                                                   3.0
# 3                                                   0.0
# 4                                                   0.0
# 5                                                   0.0
# ...                                                 ...
# 3869                                               10.8
# 3870                                               33.6
# 3871                                               16.3
# 3872                                               10.2
# 3873                                                9.8
#
# 0     Married-couple families!!Margin of Error!!$200,000 or more  \
# 1                                                   8.6
# 2                                                   2.1
# 3                                                  44.2
# 4                                                   8.7
# 5                                                  15.0
# ...                                                 ...
# 3869                                               15.9
# 3870                                               18.5
# 3871                                                3.6
# 3872                                                9.1
# 3873                                                7.9
#
# 0     Households!!Estimate!!Mean income (dollars)  \
# 1                                         50057.0
# 2                                         69452.0
# 3                                         65527.0
# 4                                         50413.0
# 5                                         77058.0
# ...                                           ...
# 3869                                     110779.0
# 3870                                     101427.0
# 3871                                     111536.0
# 3872                                      48096.0
# 3873                                      57437.0
#
# 0     Households!!Margin of Error!!Mean income (dollars)  \
# 1                                                7443.0
# 2                                                6380.0
# 3                                               28396.0
# 4                                                9122.0
# 5                                               17258.0
# ...                                                 ...
# 3869                                            38616.0
# 3870                                            31811.0
# 3871                                             7509.0
# 3872                                             7773.0
# 3873                                             8553.0
#
# 0     Households!!Estimate!!PERCENT IMPUTED!!Household income in the past 12 months  \
# 1                                                  29.9
# 2                                                  18.7
# 3                                                  35.6
# 4                                                  24.1
# 5                                                  60.5
# ...                                                 ...
# 3869                                               13.6
# 3870                                               37.3
# 3871                                               36.2
# 3872                                               26.7
# 3873                                               62.4
#
# 0     Families!!Estimate!!PERCENT IMPUTED!!Family income in the past 12 months  \
# 1                                                  31.8
# 2                                                  19.1
# 3                                                  35.6
# 4                                                  21.0
# 5                                                  65.2
# ...                                                 ...
# 3869                                               11.7
# 3870                                               37.3
# 3871                                               34.6
# 3872                                               31.5
# 3873                                               70.2
#
# 0     ACSST5Y2011.S1901-Data.csv  zip_code  year
# 1     ACSST5Y2011.S1901-Data.csv   81324.0  2011
# 2     ACSST5Y2011.S1901-Data.csv   82930.0  2011
# 3     ACSST5Y2011.S1901-Data.csv   83312.0  2011
# 4     ACSST5Y2011.S1901-Data.csv   83342.0  2011
# 5     ACSST5Y2011.S1901-Data.csv   84001.0  2011
# ...                          ...       ...   ...
# 3869  ACSST5Y2023.S1901-Data.csv   84783.0  2023
# 3870  ACSST5Y2023.S1901-Data.csv   84784.0  2023
# 3871  ACSST5Y2023.S1901-Data.csv   84790.0  2023
# 3872  ACSST5Y2023.S1901-Data.csv   86044.0  2023
# 3873  ACSST5Y2023.S1901-Data.csv   86514.0  2023
#
# [3861 rows x 77 columns]

# %% [markdown]
# ## Export Processed Data

# %%
#Optional Export to csv
#imputed_df.to_csv('2011_2023_poverty_data_utah_by_zip.csv')
